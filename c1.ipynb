# %%
import  numpy as np
import pandas as pd

df = pd.read_csv('country-who-have-send.csv')
df
# Out:
#      Official Name of Satellite Country/Organization of UN Registry  \
# 0                      AAUSat-4                                  NR
# 1                         ABS-2                                  NR
# 2                        ABS-2A                                  NR
# 3                         ABS-3                         Philippines
# 4                        ABS-3A                                  NR
# ...                         ...                                 ...
# 1415                Zhongxing 9                               China
# 1416                   Zijing 1                                  NR
# 1417               Ziyuan 1-02C                               China
# 1418                   Ziyuan 3                               China
# 1419                  Ziyan 3-2                                  NR
#
#                                          Operator/Owner  \
# 0                                 University of Aalborg
# ...

# %%
#Activity task 1 get the unique Country names

names = df['Country of Operator/Owner']
obj_to_list = names.tolist()
unique_list = np.unique(obj_to_list)
for item in unique_list:
    print(item)
# Out:
# Algeria
# Argentina
# Australia
# Austria
# Azerbaijan
# Belarus
# Belgium
# Bolivia
# Brazil
# Canada
# Chile
# China
# China/Brazil
# Denmark
# ESA
# ESA/USA
# ESA/USA/Russia
# Egypt
# France
# France/Belgium/Sweden
# France/Italy
# France/Italy/Belgium/Spain/Greece
# France/USA
# Germany
# Germany/USA
# Greece
# India
# India/Canada
# India/France
# Indonesia
# Indonesia/Philippines/Thailand
# Iran
# Iraq
# Israel
# Italy
# Japan
# Japan/USA
# Kazakhstan
# Laos
# Luxembourg
# Malaysia
# Mexico
# Morocco/Germany
# Multinational
# Netherlands
# Nigeria
# Norway
# Pakistan
# Peru
# Russia
# Russia
# Russia/Multinational
# Russia/USA
# Saudi Arabia
# Singapore
# Singapore/Taiwan
# South Africa
# South Korea
# Spain
# Sweden
# Switzerland
# Taiwan
# Taiwan/USA
# Thailand
# Turkey
# Turkey/France
# Turkmenistan/Monaco
# USA
# USA/Argentina
# USA/Canada
# USA/Canada/Japan
# USA/France
# USA/Japan
# USA/Japan/Brazil
# USA/United Kingdom/Italy
# Ukraine
# United Arab Emirates
# ...

# %%
#Activity task 2 plot the top 5 Country/Organization Name who has Satellites In Orbit
from matplotlib import pyplot as plt

df = pd.read_csv('country_satellites.csv')
df
# Out:
#                            Country/Organization Name  Satellites In Orbit
# 0                                      UNITED STATES               2825.0
# 1   COMMONWEALTH OF INDEPENDENT STATES (FORMER USSR)               1535.0
# 2                         PEOPLE'S REPUBLIC OF CHINA                436.0
# 3                                              JAPAN                188.0
# 4                                     UNITED KINGDOM                154.0
# ..                                               ...                  ...
# 86                                          SLOVAKIA                  1.0
# 87                               TURKMENISTAN/MONACO                  1.0
# 88                              UNITED STATES/BRAZIL                  1.0
# 89                                           URUGUAY                  1.0
# 90                                               NaN                  NaN
#
# [91 rows x 2 columns]

# %%
top_5 = df.head(6)
name = top_5['Country/Organization Name'].tolist()
number = top_5['Satellites In Orbit']


plt.xlabel("Country/Organization Name")
plt.xticks(rotation='vertical')
plt.ylabel("Satellites In Orbit")


label = name
size = number 
plt.bar(label, size,width=0.4, color=('red','blue','green','pink','yellow')) #bar-grap
# Out:
# <BarContainer object of 6 artists>
